# %% [markdown]
# # SciMatch tutorial

# %% [markdown]
# ### Import necessary packages

# %%
from my_class import SciMatch

# %% [markdown]
# ### Load Papers from Input

# %%
from os.path import join, dirname
from dotenv import load_dotenv

dotenv_path = './.env' #contains credentials
load_dotenv(dotenv_path)
# Out:
# True

# %%
object = SciMatch()
docs = object.get_research_topic(research_topic="covid-19", top_k=3)
docs
# Out:
# Debug: documentloader_fromprompt called with research_topic='covid-19' and top_k='3'
# Debug: Loaded 3 documents
# ...

# %%
parsedInfo=object.document_to_df(docs)
parsedInfo
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# For displaying lets order the columns:

# %%
paper_df=object.get_paperInfo(parsedInfo)
paper_df
# Out:
#                                                                                                                                                                                                                                                 Title  \
# 0                                                                                                                 Disclosure Patterns of Opioid Use Disorders in Perinatal Care During the Opioid Epidemic on X From 2019 to 2021: Thematic Analysis.
# 1  {'i': 'Conversation Cards for Adolescents', 'sup': '©', '#text': 'Testing the Feasibility, User Experiences, and Preliminary Effect of  For Behavior Change and Collaborative Goal Setting in Primary Care: A Pilot Randomized Controlled Trial.'}
# 2                                                                                                                                                                                    Post-COVID-19 Condition Fatigue Outcomes Among Danish Residents.
#
# ...

# %% [markdown]
# ### Fetching Authors of the Papers and generate location

# %%
pmid_authors_df=object.get_authorsInfo_from_parsed_Info(parsedInfo)
pmid_authors_df
# Out:
#        forename        lastname  \
# 0             A           Eaton
# 1        Anders           Hviid
# 2        Anders            Koch
# 3    Anna Irene  Vedel Sørensen
# 4             B           Islam
# 5       Bankole         Olatosi
# 6     Constance          Guille
# 7         Dezhi              Wu
# 8     Elisabeth         O'Regan
# 9           Gdc            Ball
# 10       Ingrid  Bech Svalgaard
# 11     Jennifer           Fillo
# 12       Jiajia           Zhang
# 13           Jl         Wincott
# 14            K          Talwar
# 15        Kacey    Eichelberger
# 16      Lampros    Spiliopoulos
# 17            M           Kebbe
# 18            M         Yaskina
# 19       Minnie              Ng
# 20           Mp           Dyson
# 21    Nete Munk         Nielsen
# 22       Peiyin            Hung
# 23        Peter           Bager
# 24      Phyllis          Raynor
# 25         Poul        Videbech
# 26  Saborny Sen           Gupta
# 27           Sd           Scott
# ...

# %% [markdown]
# For displaying we only need some of the columns:

# %%
displaying_df=object.display_df(pmid_authors_df)
displaying_df
# Out:
#        Forename        Lastname  \
# 0             A           Eaton
# 1        Anders           Hviid
# 2        Anders            Koch
# 3    Anna Irene  Vedel Sørensen
# 4             B           Islam
# 5       Bankole         Olatosi
# 6     Constance          Guille
# 7         Dezhi              Wu
# 8     Elisabeth         O'Regan
# 9           Gdc            Ball
# 10       Ingrid  Bech Svalgaard
# 11     Jennifer           Fillo
# 12       Jiajia           Zhang
# 13           Jl         Wincott
# 14            K          Talwar
# 15        Kacey    Eichelberger
# 16      Lampros    Spiliopoulos
# 17            M           Kebbe
# 18            M         Yaskina
# 19       Minnie              Ng
# 20           Mp           Dyson
# 21    Nete Munk         Nielsen
# 22       Peiyin            Hung
# 23        Peter           Bager
# 24      Phyllis          Raynor
# 25         Poul        Videbech
# 26  Saborny Sen           Gupta
# 27           Sd           Scott
# ...

# %% [markdown]
# ### Create a Map:

# %%
pmid_authors_df=pmid_authors_df.dropna(subset=['latitude', 'longitude'])
map=object.authors_on_worldmap(pmid_authors_df)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Create a Network:

# %%
# needed to highlight the authors in the nodes
paper_main_authors, updated_pmid_authors_df = object.define_main_authors(parsedInfo, pmid_authors_df)
paper_main_authors
# Out:
#         uid       first_author      last_author
# 0  39374068           Dezhi Wu  Bankole Olatosi
# 1  39374045            M Kebbe         Gdc Ball
# 2  39374018  Elisabeth O'Regan     Anders Hviid

# %%
net = object.authors_in_network(pmid_authors_df, parsedInfo, paper_main_authors, ss_treshold=0.2)
net.save_graph("authors_network.html")
from IPython.display import IFrame
IFrame("authors_network.html", width=800, height=600)
# Out:
# /home/melanie/Unistuff/SoSe24/SciMatch_Git/SciMatch/makingnetwork.py:36: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   fused_authors_df = fused_authors_df.applymap(lambda x: float(x) if isinstance(x, np.float32) else x)
#         <iframe
#             width="800"
#             height="600"
#             src="authors_network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
